# %%
import pandas as pd
import requests
import string

# %%
# Import data
data_init = pd.read_excel('data/NLP_Data.xlsx')

# %%
# Dataframe containg the data that our team created
data_init.head()
# Out:
#                    Text Command Topic Identifier       Action  \
# 0  assign completed status to X  Task          X    Completed
# 1           move X to completed  Task          X    Completed
# 2                   X completed  Task          X    Completed
# 3                   Completed X  Task          X    Completed
# 4                 X in progress  Task          X  In Progress
#
#   One Hot Encoded Topic One Hot Encoded Action    Verb/Noun
# 0                 [1,0]            [0,0,0,0,1]       assign
# 1                 [1,0]            [0,0,0,0,1]         move
# 2                 [1,0]            [0,0,0,0,1]    completed
# 3                 [1,0]            [0,0,0,0,1]    completed
# 4                 [1,0]            [0,1,0,0,0]  in progress

# %% [markdown]
# ## Augmenting total data for modeling purposes:

# %%
# Script for creating new data by substituting words for their synonyms. Only the words which are not included
# in the identifier are eligible for being replaced
def aug_data(df, syn_num):
    #new dataframe for the new sentences
    added_data = pd.DataFrame(columns=list(df.columns))
    index = len(df)
    for i in range(len(df.index)):
        identifier = df.iloc[i][2]
        text = df.iloc[i][0]
        sentence_lst = text.split()
        # identifier_lst = identifier.split()
        
        # List of additional words that translating did not make sense
        identifier_lst = ['a', 'an']
        identifier_lst.append(identifier.split()[0])

        for j in range(len(sentence_lst)):
            word = sentence_lst[j]
            if word not in identifier_lst:
                word = word.lower()
                
                # max=syn_num is the number of synonyms you want for each non-identifier word in the cmd
                
                api_url = 'https://api.datamuse.com/words?rel_syn={0}&max='.format(word)
                api_url += str(syn_num)
                word_synonyms = requests.get(api_url)
                word_synonyms = word_synonyms.json()
                
                for k in range(len(word_synonyms)):
                    new_sentence_lst = sentence_lst[:j]+[word_synonyms[k]['word']]+sentence_lst[j+1:]
                    s = " "
                    new_sentence = s.join(new_sentence_lst)
                    added_data.loc[index] = [new_sentence] + list(df.loc[i][1:])
                    index += 1
                    
    augmented_data = pd.concat([df,added_data])
    return augmented_data

# %%
new_data = aug_data(data_init, 5)

# %%
new_data
# Out:
#                       Text Command    Topic Identifier       Action  \
# 0     assign completed status to X     Task          X    Completed
# 1              move X to completed     Task          X    Completed
# 2                      X completed     Task          X    Completed
# 3                      Completed X     Task          X    Completed
# 4                    X in progress     Task          X  In Progress
# ...                            ...      ...        ...          ...
# 2602           X project is on dog  Project          X    On Target
# 2603          X project is on lead  Project          X    On Target
# 2604        X project is on course  Project          X    On Target
# 2605         X project is on cross  Project          X    On Target
# 2606         X project is on cover  Project          X    On Target
#
#      One Hot Encoded Topic One Hot Encoded Action    Verb/Noun
# 0                    [1,0]            [0,0,0,0,1]       assign
# 1                    [1,0]            [0,0,0,0,1]         move
# 2                    [1,0]            [0,0,0,0,1]    completed
# 3                    [1,0]            [0,0,0,0,1]    completed
# 4                    [1,0]            [0,1,0,0,0]  in progress
# ...                    ...                    ...          ...
# 2602                 [0,1]            [0,1,0,0,0]     on track
# 2603                 [0,1]            [0,1,0,0,0]     on track
# 2604                 [0,1]            [0,1,0,0,0]     on track
# 2605                 [0,1]            [0,1,0,0,0]     on track
# 2606                 [0,1]            [0,1,0,0,0]     on track
#
# [2607 rows x 7 columns]

# %%
new_data.to_csv('data/Augmented_Data.csv', index=False)

# %% [markdown]
# ## Augmenting specified actions/rows for exploration purposes:

# %%
# pd.set_option("display.max_rows", 10)

# %%
# Limiting data to just completed tasks for API exploration purposes
data_action5 = data_init[data_init.Action == 'Completed'].reset_index(drop=True)
data_action5
# Out:
#                     Text Command Topic Identifier     Action  \
# 0   assign completed status to X  Task          X  Completed
# 1            move X to completed  Task          X  Completed
# 2                    X completed  Task          X  Completed
# 3                    Completed X  Task          X  Completed
# 4                 X is completed  Task          X  Completed
# 5                     X complete  Task          X  Completed
# 6                X was completed  Task          X  Completed
# 7                 X was complete  Task          X  Completed
# 8                  X is complete  Task          X  Completed
# 9               Task X completed  Task          X  Completed
# 10              X task completed  Task          X  Completed
# 11              Completed task X  Task          X  Completed
# 12              Completed X task  Task          X  Completed
# 13           Task X is completed  Task          X  Completed
# 14           X task is completed  Task          X  Completed
# 15               Task X complete  Task          X  Completed
# 16               X task complete  Task          X  Completed
# 17          Task X was completed  Task          X  Completed
# 18          X task was completed  Task          X  Completed
# 19           X task was complete  Task          X  Completed
# 20           Task X was complete  Task          X  Completed
# 21            Task X is complete  Task          X  Completed
# 22            X task is complete  Task          X  Completed
# 23               Finished with Y  Task          Y  Completed
#
#    One Hot Encoded Topic One Hot Encoded Action  Verb/Noun
# 0                [1,0,0]            [0,0,0,0,1]     assign
# 1                [1,0,0]            [0,0,0,0,1]       move
# 2                [1,0,0]            [0,0,0,0,1]  completed
# 3                [1,0,0]            [0,0,0,0,1]  completed
# 4                [1,0,0]            [0,0,0,0,1]         is
# 5                [1,0,0]            [0,0,0,0,1]       None
# 6                [1,0,0]            [0,0,0,0,1]        was
# 7                [1,0,0]            [0,0,0,0,1]        was
# 8                [1,0,0]            [0,0,0,0,1]         is
# 9                [1,0,0]            [0,0,0,0,1]  completed
# 10               [1,0,0]            [0,0,0,0,1]  completed
# 11               [1,0,0]            [0,0,0,0,1]  completed
# 12               [1,0,0]            [0,0,0,0,1]  completed
# 13               [1,0,0]            [0,0,0,0,1]         is
# 14               [1,0,0]            [0,0,0,0,1]         is
# 15               [1,0,0]            [0,0,0,0,1]       None
# 16               [1,0,0]            [0,0,0,0,1]       None
# 17               [1,0,0]            [0,0,0,0,1]        was
# 18               [1,0,0]            [0,0,0,0,1]        was
# 19               [1,0,0]            [0,0,0,0,1]        was
# 20               [1,0,0]            [0,0,0,0,1]        was
# 21               [1,0,0]            [0,0,0,0,1]         is
# 22               [1,0,0]            [0,0,0,0,1]         is
# 23               [1,0,0]            [0,0,0,0,1]   finished

# %%
# Running the script for just the first X rows
data_action5_aug = aug_data(data_action5.iloc[0:5], 5)

# %%
data_action5_aug
# Out:
#                        Text Command Topic Identifier     Action  \
# 0      assign completed status to X  Task          X  Completed
# 1               move X to completed  Task          X  Completed
# 2                       X completed  Task          X  Completed
# 3                       Completed X  Task          X  Completed
# 4                    X is completed  Task          X  Completed
# 5         put completed status to X  Task          X  Completed
# 6   attribute completed status to X  Task          X  Completed
# 7     ascribe completed status to X  Task          X  Completed
# 8    delegate completed status to X  Task          X  Completed
# 9   designate completed status to X  Task          X  Completed
# 10      assign complete status to X  Task          X  Completed
# 11  assign accomplished status to X  Task          X  Completed
# 12      assign realized status to X  Task          X  Completed
# 13   assign consummated status to X  Task          X  Completed
# 14  assign completed condition to X  Task          X  Completed
# 15   assign completed position to X  Task          X  Completed
# 16               run X to completed  Task          X  Completed
# 17                go X to completed  Task          X  Completed
# 18            affect X to completed  Task          X  Completed
# 19            strike X to completed  Task          X  Completed
# 20               act X to completed  Task          X  Completed
# 21               move X to complete  Task          X  Completed
# 22           move X to accomplished  Task          X  Completed
# 23               move X to realized  Task          X  Completed
# 24            move X to consummated  Task          X  Completed
# 25                       X complete  Task          X  Completed
# 26                   X accomplished  Task          X  Completed
# 27                       X realized  Task          X  Completed
# 28                    X consummated  Task          X  Completed
# 29                       complete X  Task          X  Completed
# 30                   accomplished X  Task          X  Completed
# 31                       realized X  Task          X  Completed
# 32                    consummated X  Task          X  Completed
# 33                    X is complete  Task          X  Completed
# 34                X is accomplished  Task          X  Completed
# 35                    X is realized  Task          X  Completed
# 36                 X is consummated  Task          X  Completed
#
#    One Hot Encoded Topic One Hot Encoded Action  Verb/Noun
# 0                [1,0,0]            [0,0,0,0,1]     assign
# 1                [1,0,0]            [0,0,0,0,1]       move
# 2                [1,0,0]            [0,0,0,0,1]  completed
# 3                [1,0,0]            [0,0,0,0,1]  completed
# 4                [1,0,0]            [0,0,0,0,1]         is
# 5                [1,0,0]            [0,0,0,0,1]     assign
# 6                [1,0,0]            [0,0,0,0,1]     assign
# 7                [1,0,0]            [0,0,0,0,1]     assign
# 8                [1,0,0]            [0,0,0,0,1]     assign
# 9                [1,0,0]            [0,0,0,0,1]     assign
# 10               [1,0,0]            [0,0,0,0,1]     assign
# 11               [1,0,0]            [0,0,0,0,1]     assign
# 12               [1,0,0]            [0,0,0,0,1]     assign
# 13               [1,0,0]            [0,0,0,0,1]     assign
# 14               [1,0,0]            [0,0,0,0,1]     assign
# 15               [1,0,0]            [0,0,0,0,1]     assign
# 16               [1,0,0]            [0,0,0,0,1]       move
# 17               [1,0,0]            [0,0,0,0,1]       move
# 18               [1,0,0]            [0,0,0,0,1]       move
# 19               [1,0,0]            [0,0,0,0,1]       move
# 20               [1,0,0]            [0,0,0,0,1]       move
# 21               [1,0,0]            [0,0,0,0,1]       move
# 22               [1,0,0]            [0,0,0,0,1]       move
# 23               [1,0,0]            [0,0,0,0,1]       move
# 24               [1,0,0]            [0,0,0,0,1]       move
# 25               [1,0,0]            [0,0,0,0,1]  completed
# 26               [1,0,0]            [0,0,0,0,1]  completed
# 27               [1,0,0]            [0,0,0,0,1]  completed
# 28               [1,0,0]            [0,0,0,0,1]  completed
# 29               [1,0,0]            [0,0,0,0,1]  completed
# 30               [1,0,0]            [0,0,0,0,1]  completed
# 31               [1,0,0]            [0,0,0,0,1]  completed
# 32               [1,0,0]            [0,0,0,0,1]  completed
# 33               [1,0,0]            [0,0,0,0,1]         is
# 34               [1,0,0]            [0,0,0,0,1]         is
# 35               [1,0,0]            [0,0,0,0,1]         is
# 36               [1,0,0]            [0,0,0,0,1]         is
